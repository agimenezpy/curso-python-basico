# %% [markdown]
# Ejercicios con Diccionarios
# ============================
#
#
# ### A\. Contador de palabras
# Crear una funcion que reciba una cadena con palabras e imprimir la frecuencia de las palabras en la pantalla.
#
# ```python
# def wordcount(nombre_archivo):
#     # El codigo aqui
#     return dic
# ```
#
#
# ### B\. Probar la funcion wordcount
# Leer el archivo de manera secuencial y utilizar diccionarios para contar las ocurrencias. Ej. Almacene la cadena siguiente en una variable `small`
#
# ```python
# small = """
# We are not what we should be
# We are not what we need to be
# But at least we are not what we used to be
#   -- Football Coach
# """
# ```
#
# ### C\. Temperaturas de paraguay
# Crear el diccionario de la cadena  `datos_paraguay` con la siguiente información. El espacio entre datos es el caracter TAB.
#
# ```python
# datos_paraguay = """Ciudad	Precip	Temp
# Mariscal Estigarribia	989.4	2.7
# Puerto Casado	1001.1	27.7
# Pedro Juan	948.3	24.3
# Pozo Colorado	998.1	28.8
# Concepcion	1001.3	27.5
# Gral. Bruguez	997.6	28.0
# San Pedro	1001.3	27.4
# San Estanislao	989.4	28.3
# Saltos Del Guaira	976.3	26.4
# Asuncion	1000.5	28.6
# Paraguari	997.7	28.8
# Villarrica	991.3	27.6
# Cnel. Oviedo	987.7	27.3
# Aeropuerto Guarani	982.7	26.8
# San Juan Bautista	994.7	27.4
# Caazapa	993.0	27.2
# Capitan Meza	982.5	25.5
# Encarnacion	995.8	27.7
# """
# ```
#
# * Leer la cadena linea por linea y depositar en un diccionario que contenga como clave la _ciudad_ y como valor los valores de precipitación y temperatura lista.
# * Convertir los valores numéricos
#
#   Contestar las siguientes preguntas
#
# * ¿Cuál es la temperatura promedio?
# * ¿Cuál es la temperatura máxima? En qué ciudad?
# * ¿Cuál es la temperatura mínima? En qué ciudad?
# * ¿Cuál es la precipitación acumulada?
