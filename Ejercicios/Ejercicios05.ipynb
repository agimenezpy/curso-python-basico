# %% [markdown]
# Ejercicios con Listas
# ======================
#
# ### A\. match_ends
# Dada una lista de cadenas, retornar la cantidad de los números de cadenas donde la longitud es `2` o mayor, y el primer y último caracter de la cadena son iguales.
#
# _Ayuda_: En python no existe el operador posincremento `++`, pero `+=` es el equivalente.
#
# ```python
# def match_ends(words):
#     # +++your code here+++
#     return
# ```
#
# ### B\. front_x
# Dada una lista de cadenas, returnar una lista con las cadenas en orden, a excepción de las cadenas que empiecen con `'x'` deben estar al inicio.
#
# Ej. `['mix', 'xyz', 'apple', 'xanadu', 'aardvark']` retorna `['xanadu', 'xyz', 'aardvark', 'apple', 'mix']`
#
# _Ayuda_: Esto puede realizarse utilizando 2 listas y ordendo ambas por separado antes de combinarlas
#
# ```python
# def front_x(words):
#     # +++your code here+++
#     return
# ```
#
# ### C\. sort_last
# Dada una lista de tuplas no vacias, retornar una lista ordenada en forma ascendente escogiendo el último elemento de cada tupla.
#
# Ej. `[(1, 7), (1, 3), (3, 4, 5), (2, 2)]` devuelve `[(2, 2), (1, 3), (3, 4, 5), (1, 7)]`
#
# _Ayuda_: Utilizar el parámetro de función key= para extraer el último item de la lista.
#
# ```python
# def sort_last(tuples):
#     # +++your code here+++
#     return
# ```
#
# ### D\. remove_adjacent
# Dada una lista de numeros, retornar una lista donde todos los elementos adjacentes iguales `==` sean reducidos a un solo elemento.
#
# Así que `[1, 2, 2, 3]` retornaria `[1, 2, 3]`. Puede crear una nueva lista o modificar la lista que se paso como parámetro.
#
# ```python
# def remove_adjacent(nums):
#     # +++your code here+++
#     return
# ```
#
# ### E\. linear_merge
# Dadas 2 listas en orden ascendente, crear y retornar una lista mezclada de todos los elementos ordenados.
#
# Podrá modificar la lista. Idealmente la solución debe funcionar en tiempo lineal, recorriendo ambas listas solo una vez.
#
# ```python
# def linear_merge(list1, list2):
#     # +++your code here+++
#     return
# ```
